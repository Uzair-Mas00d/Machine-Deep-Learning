# %%
# !git clone https://github.com/Unity-Technologies/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 92563, done.
# remote: Counting objects: 100% (496/496), done.
# remote: Compressing objects: 100% (300/300), done.
# remote: Total 92563 (delta 192), reused 409 (delta 138), pack-reused 92067
# Receiving objects: 100% (92563/92563), 2.89 GiB | 33.68 MiB/s, done.
# Resolving deltas: 100% (67357/67357), done.
# Updating files: 100% (2215/2215), done.

# %%
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents
# Out:
# /content/ml-agents
# Obtaining file:///content/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: mlagents-envs
#     Found existing installation: mlagents-envs 1.1.0.dev0
#     Uninstalling mlagents-envs-1.1.0.dev0:
#       Successfully uninstalled mlagents-envs-1.1.0.dev0
#   Running setup.py develop for mlagents-envs
# ...
# Obtaining file:///content/ml-agents/ml-agents
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
# ...
#   Using cached cattrs-1.5.0-py3-none-any.whl (19 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...

# %%
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !gdown --id '1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL'
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL
# From (redirected): https://drive.google.com/uc?id=1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL&confirm=t&uuid=ff227222-e47a-4471-9de2-ec2ce25570e3
# To: /content/ml-agents/SoccerTwos.zip
# 100% 37.0M/37.0M [00:00<00:00, 77.4MB/s]

# %%
# !unzip -d ./training-envs-executables/linux/ ./SoccerTwos.zip
# Out:
# Archive:  ./SoccerTwos.zip
#    creating: ./training-envs-executables/linux/SoccerTwos_Data/
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/app.info
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/boot.config
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/globalgamemanagers
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/globalgamemanagers.assets
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/level0
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/level0.resS
#    creating: ./training-envs-executables/linux/SoccerTwos_Data/Managed/
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/Managed/Assembly-CSharp.dll
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/Managed/Google.Protobuf.dll
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/Managed/Grpc.Core.dll
# ...

# %%
# !chmod -R 755 /content/ml-agents/./training-envs-executables/linux/SoccerTwos.x86_64

# %%
# !mlagents-learn ./config/poca/SoccerTwos.yaml --env=./training-envs-executables/linux/SoccerTwos.x86_64 --run-id="SoccerTwos" --no-graphics --force
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:696: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
# 2024-04-24 15:19:10.034595: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-24 15:19:10.034645: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-24 15:19:10.187977: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !huggingface-cli login

# %%
# !mlagents-push-to-hf  --run-id="SoccerTwos"  --local-dir="./results/SoccerTwos"  --repo-id="UXAIR/poca-SoccerTwos"  --commit-message="First Push"
